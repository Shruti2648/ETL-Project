# %% [markdown]
# # New York Tuition Assistance Program (TAP) Data ETL
#
# In this project, we will perform ETL on data related to the New York State Tuition Assistance Program (TAP). We will use two datasets provided by NYC Open Data. The first dataset contains information on TAP recipients by college, sector group, and level of study. The second dataset contains information on TAP recipients by income, age group, and program information. Both datasets contain a field for TAP Sector Group, which consists of categories for New York colleges. Our goal is to transform and load the data into a Postgres SQL database as two tables that have the TAP Sector Group key in common.

# %% [markdown]
# Below are links to the data source:
#
# https://data.ny.gov/Education/Tuition-Assistance-Program-TAP-Recipients-Dollars-/ich7-7ewa
#
# https://data.ny.gov/Education/Tuition-Assistance-Program-TAP-Recipients-Dollars-/2t78-bs45

# %% [markdown]
# # Part 1: Read data and verify that datasets are related:

# %%
# Import dependencies:

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read our first dataset, which contains data on TAP recipients by college, sector group, and level of study:

tap_college_df = pd.read_csv("TAP_Recipients_College_Sector_Group_and_Level_of_Study.csv")
tap_college_df
# Out:
#        Academic Year  TAP College Code  Federal School Code Level  \
# 0               2018              7738                20937     U
# 1               2018              7131                 5208     U
# 2               2018              6121                 5208     U
# 3               2018              1417                 2698     U
# 4               2018               405                 2758     U
# ...              ...               ...                  ...   ...
# 10228           2000               140                 2705     U
# 10229           2000               270                 2728     U
# 10230           2000               535                20662     U
# 10231           2000               960                 2668     U
# 10232           2000              5155                 9895     G
#
#       TAP Level of Study                   TAP College Name Sector Type  \
# 0         2 yr Undergrad   LONG ISLAND BUS INST UG SEMESTER     PRIVATE
# 1         2 yr Undergrad  COLL WESTCHESTER ONLINE ASSOC EVE     PRIVATE
# 2         4 yr Undergrad       COLL WESTCHESTER 4YR BBA EVE     PRIVATE
# 3         5 yr Undergrad             CUNY COL STATEN ISLAND      PUBLIC
# 4         4 yr Undergrad   MANHATTAN COLLEGE 4 YR UNDERGRAD     PRIVATE
# ...                  ...                                ...         ...
# 10228     2 yr Undergrad       COLLEGE OF SAINT ROSE 4YR UG     PRIVATE
# 10229     4 yr Undergrad                   HAMILTON COLLEGE     PRIVATE
# 10230     4 yr Undergrad       THE NEW SCHOOL 4YR UNDERGRAD     PRIVATE
# 10231     4 yr Undergrad  SUC CERAMICS AT ALFRED UNIV 4YR U      PUBLIC
# 10232               Grad      YESHIVA UNIV EINSTEIN COL MED     PRIVATE
#
#       TAP Sector Group  TAP Recipient Headcount  TAP Recipient FTEs  \
# 0        6-BUS. DEGREE                     1177              900.92
# 1        6-BUS. DEGREE                        9                6.78
# 2        6-BUS. DEGREE                       62               40.15
# 3            1-CUNY SR                       37               26.91
# 4        5-INDEPENDENT                      943              871.14
# ...                ...                      ...                 ...
# 10228    5-INDEPENDENT                        4                2.50
# 10229    5-INDEPENDENT                      353              347.50
# 10230    5-INDEPENDENT                      562              505.75
# 10231        3-SUNY SO                      297              274.00
# 10232    5-INDEPENDENT                       73               72.50
#
#        TAP Recipient Dollars
# 0                 3059747.88
# 1                   30273.44
# 2                  125711.87
# 3                  115458.47
# 4                 2812592.21
# ...                      ...
# 10228                9206.00
# 10229              734461.00
# 10230             1517281.25
# 10231              471216.75
# 10232               29704.50
#
# [10233 rows x 11 columns]

# %%
# Read our second dataset, which contains data on TAP recipients by income, age group, and program information:

tap_income_df = pd.read_csv("TAP_Recipients_Income_Age_Group_and_Program_information.csv")
tap_income_df
# Out:
#         Academic Year Level TAP Level of Study Sector Type TAP Sector Group  \
# 0                2018     U     4 yr Undergrad      PUBLIC        3-SUNY SO
# 1                2018     U     4 yr Undergrad      PUBLIC        3-SUNY SO
# 2                2018     U     4 yr Undergrad      PUBLIC        3-SUNY SO
# 3                2018     U     5 yr Undergrad      PUBLIC        3-SUNY SO
# 4                2018     U     4 yr Undergrad     PRIVATE    6-BUS. DEGREE
# ...               ...   ...                ...         ...              ...
# 218999           2000     U     2 yr Undergrad      PUBLIC        1-CUNY SR
# 219000           2000     U     2 yr Undergrad      PUBLIC        2-CUNY CC
# 219001           2000     U     2 yr Undergrad      PUBLIC        4-SUNY CC
# 219002           2000     U     2 yr Undergrad     PRIVATE          8-OTHER
# 219003           2000     U     4 yr Undergrad      PUBLIC        1-CUNY SR
#
#        Recipient Age Group   TAP Financial Status     TAP Award Schedule  \
# 0              age 22 - 25  Financial_Independent  Married_No_Dependents
# 1              age 22 - 25  Financial_Independent   Independent_Schedule
# 2              age 36 - 50  Financial_Independent     Dependent_Schedule
# 3              age 22 - 25    Financial_Dependent     Dependent_Schedule
# 4              age 26 - 35  Financial_Independent     Dependent_Schedule
# ...                    ...                    ...                    ...
# 218999         age 26 - 35  Financial_Independent     Dependent_Schedule
# 219000        under age 22    Financial_Dependent     Dependent_Schedule
# 219001         age 26 - 35    Financial_Dependent     Dependent_Schedule
# 219002         age 26 - 35  Financial_Independent     Dependent_Schedule
# 219003         age 36 - 50  Financial_Independent     Dependent_Schedule
#
#        TAP Degree or NonDegree TAP Schedule Letter Income by $1,000 Range  \
# 0                       Degree                   C     $35,001 to $36,000
# 1                       Degree                   M     $ 3,001 to $ 4,000
# 2                       Degree                   E     $44,001 to $45,000
# 3                       Degree                   E     $66,001 to $67,000
# 4                       Degree                   E     $26,001 to $27,000
# ...                        ...                 ...                    ...
# 218999                  Degree                   D     $54,001 to $55,000
# 219000                  Degree                   E     $44,001 to $45,000
# 219001                  Degree                   D     $33,001 to $34,000
# 219002                  Degree                   E     $24,001 to $25,000
# 219003                  Degree                   A     $ 5,001 to $ 6,000
#
#        Income by $5,000 Range Income by $10,000 Range  \
# 0          $35,001 to $40,000      $30,001 to $40,000
# 1          $     1 to $ 5,000      $     0 to $10,000
# 2          $40,001 to $45,000      $40,001 to $50,000
# 3          $65,001 to $70,000      $60,001 to $70,000
# 4          $25,001 to $30,000      $20,001 to $30,000
# ...                       ...                     ...
# 218999     $50,001 to $55,000      $50,001 to $60,000
# 219000     $40,001 to $45,000      $40,001 to $50,000
# 219001     $30,001 to $35,000      $30,001 to $40,000
# 219002     $20,001 to $25,000      $20,001 to $30,000
# 219003     $ 5,001 to $10,000      $     0 to $10,000
#
#         TAP Recipient  Headcount  TAP Recipient FTEs  TAP Recipient Dollars
# 0                              2                1.51                 755.41
# 1                             67               50.11              139222.46
# 2                              1                0.50                 528.79
# 3                              1                1.01                 503.61
# 4                             11                9.37               29082.87
# ...                          ...                 ...                    ...
# 218999                         1                0.75                 318.75
# 219000                        27               21.50                9137.50
# 219001                         2                1.00                 425.00
# 219002                         1                0.33                1067.33
# 219003                        13                7.67               22170.60
#
# [219004 rows x 16 columns]

# %%
# Verify that both datasets contain the same unique values in the TAP Sector Group column:

tap_sector_groups_1 = tap_college_df["TAP Sector Group"].unique()
tap_sector_groups_2 = tap_income_df["TAP Sector Group"].unique()

print(tap_sector_groups_1)
print(tap_sector_groups_2)
# Out:
# ['6-BUS. DEGREE' '1-CUNY SR' '5-INDEPENDENT' '4-SUNY CC' '3-SUNY SO'
#  '9-CHAPTER XXII' '2-CUNY CC' '8-OTHER' '7-BUS. NON-DEG']
# ['3-SUNY SO' '6-BUS. DEGREE' '1-CUNY SR' '5-INDEPENDENT' '9-CHAPTER XXII'
#  '4-SUNY CC' '8-OTHER' '2-CUNY CC' '7-BUS. NON-DEG']

# %% [markdown]
# # Part 2: Clean tap_college_df:

# %%
# Sort tap_college_df by TAP sector group:

tap_college_df = tap_college_df.sort_values(by=["TAP Sector Group"])
tap_college_df
# Out:
#       Academic Year  TAP College Code  Federal School Code Level  \
# 6597           2005              5216                 2693     G
# 2661           2012              1418                 4759     U
# 2662           2012              1414                 2693     U
# 2663           2012              1416                 2690     U
# 2664           2012              1415                10097     U
# ...             ...               ...                  ...   ...
# 1619           2015              8302                31473     U
# 1618           2015              8314                11670     U
# 427            2018              8266                 8614     U
# 2706           2012              8319                34963     U
# 1888           2014              8312                41381     U
#
#      TAP Level of Study                   TAP College Name Sector Type  \
# 6597               Grad         CUNY JOHN JAY COLLEGE GRAD      PUBLIC
# 2661     5 yr Undergrad                  CUNY YORK COLLEGE      PUBLIC
# 2662     4 yr Undergrad              CUNY JOHN JAY COLLEGE      PUBLIC
# 2663     5 yr Undergrad                CUNY QUEENS COLLEGE      PUBLIC
# 2664     2 yr Undergrad          CUNY MEDGER EVERS COLLEGE      PUBLIC
# ...                 ...                                ...         ...
# 1619     4 yr Undergrad                   YESHIVA D'MONSEY     PRIVATE
# 1618     4 yr Undergrad  YESHIVA OF NITRA RABBINICAL COLLE     PRIVATE
# 427      4 yr Undergrad  RABBINCAL COL BOBOVER YESHIV BNEI     PRIVATE
# 2706     4 yr Undergrad  YESHIVA SHAAREI TORAH OF ROCKLAND     PRIVATE
# 1888     4 yr Undergrad         YESHIVA OF MACHZIKAI HADAS     PRIVATE
#
#      TAP Sector Group  TAP Recipient Headcount  TAP Recipient FTEs  \
# 6597        1-CUNY SR                       88               55.75
# 2661        1-CUNY SR                       67               50.50
# 2662        1-CUNY SR                     6761             5549.25
# 2663        1-CUNY SR                      115               76.50
# 2664        1-CUNY SR                     1775             1131.50
# ...               ...                      ...                 ...
# 1619   9-CHAPTER XXII                       36               34.00
# 1618   9-CHAPTER XXII                      168              164.50
# 427    9-CHAPTER XXII                      212              220.15
# 2706   9-CHAPTER XXII                       26               23.00
# 1888   9-CHAPTER XXII                      223              220.00
#
#       TAP Recipient Dollars
# 6597               23834.50
# 2661              206874.50
# 2662            20935364.66
# 2663              334874.25
# 2664             4481339.66
# ...                     ...
# 1619              130549.50
# 1618              773792.00
# 427              1026561.52
# 2706               95904.00
# 1888             1068463.00
#
# [10233 rows x 11 columns]

# %%
# Determine which columns contain null values:

tap_college_df.columns[tap_college_df.isnull().any()]
# Out:
# Index(['TAP Recipient FTEs'], dtype='object')

# %%
# Determine what proportion of the column contains null values:

proportion_missing = tap_college_df.isnull().sum()/len(tap_college_df)
proportion_missing = proportion_missing[proportion_missing > 0]
proportion_missing.sort_values(inplace=True)
proportion_missing
# Out:
# TAP Recipient FTEs    0.000098
# dtype: float64

# %%
# Since there are only a few missing values, we will only drop rows with missing values instead of dropping any columns:

tap_college_df = tap_college_df.dropna()
tap_college_df
# Out:
#       Academic Year  TAP College Code  Federal School Code Level  \
# 6597           2005              5216                 2693     G
# 2661           2012              1418                 4759     U
# 2662           2012              1414                 2693     U
# 2663           2012              1416                 2690     U
# 2664           2012              1415                10097     U
# ...             ...               ...                  ...   ...
# 1619           2015              8302                31473     U
# 1618           2015              8314                11670     U
# 427            2018              8266                 8614     U
# 2706           2012              8319                34963     U
# 1888           2014              8312                41381     U
#
#      TAP Level of Study                   TAP College Name Sector Type  \
# 6597               Grad         CUNY JOHN JAY COLLEGE GRAD      PUBLIC
# 2661     5 yr Undergrad                  CUNY YORK COLLEGE      PUBLIC
# 2662     4 yr Undergrad              CUNY JOHN JAY COLLEGE      PUBLIC
# 2663     5 yr Undergrad                CUNY QUEENS COLLEGE      PUBLIC
# 2664     2 yr Undergrad          CUNY MEDGER EVERS COLLEGE      PUBLIC
# ...                 ...                                ...         ...
# 1619     4 yr Undergrad                   YESHIVA D'MONSEY     PRIVATE
# 1618     4 yr Undergrad  YESHIVA OF NITRA RABBINICAL COLLE     PRIVATE
# 427      4 yr Undergrad  RABBINCAL COL BOBOVER YESHIV BNEI     PRIVATE
# 2706     4 yr Undergrad  YESHIVA SHAAREI TORAH OF ROCKLAND     PRIVATE
# 1888     4 yr Undergrad         YESHIVA OF MACHZIKAI HADAS     PRIVATE
#
#      TAP Sector Group  TAP Recipient Headcount  TAP Recipient FTEs  \
# 6597        1-CUNY SR                       88               55.75
# 2661        1-CUNY SR                       67               50.50
# 2662        1-CUNY SR                     6761             5549.25
# 2663        1-CUNY SR                      115               76.50
# 2664        1-CUNY SR                     1775             1131.50
# ...               ...                      ...                 ...
# 1619   9-CHAPTER XXII                       36               34.00
# 1618   9-CHAPTER XXII                      168              164.50
# 427    9-CHAPTER XXII                      212              220.15
# 2706   9-CHAPTER XXII                       26               23.00
# 1888   9-CHAPTER XXII                      223              220.00
#
#       TAP Recipient Dollars
# 6597               23834.50
# 2661              206874.50
# 2662            20935364.66
# 2663              334874.25
# 2664             4481339.66
# ...                     ...
# 1619              130549.50
# 1618              773792.00
# 427              1026561.52
# 2706               95904.00
# 1888             1068463.00
#
# [10232 rows x 11 columns]

# %%
# Rename column headers so that they do not contain any spaces. This will be helpful when we load the data into the database:

tap_college_df.columns = ["academic_year", "tap_college_code", 
                               "federal_school_code", "level",
                               "tap_level_of_study", "tap_college_name",
                               "sector_type", "tap_sector_group",
                               "tap_recipient_headcount", "tap_recipient_ftes",
                               "tap_recipient_dollars"]

tap_college_df
# Out:
# C:\Users\jadha\Anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#       academic_year  tap_college_code  federal_school_code level  \
# 6597           2005              5216                 2693     G
# 2661           2012              1418                 4759     U
# 2662           2012              1414                 2693     U
# 2663           2012              1416                 2690     U
# 2664           2012              1415                10097     U
# ...             ...               ...                  ...   ...
# 1619           2015              8302                31473     U
# 1618           2015              8314                11670     U
# 427            2018              8266                 8614     U
# 2706           2012              8319                34963     U
# 1888           2014              8312                41381     U
#
#      tap_level_of_study                   tap_college_name sector_type  \
# 6597               Grad         CUNY JOHN JAY COLLEGE GRAD      PUBLIC
# 2661     5 yr Undergrad                  CUNY YORK COLLEGE      PUBLIC
# 2662     4 yr Undergrad              CUNY JOHN JAY COLLEGE      PUBLIC
# 2663     5 yr Undergrad                CUNY QUEENS COLLEGE      PUBLIC
# 2664     2 yr Undergrad          CUNY MEDGER EVERS COLLEGE      PUBLIC
# ...                 ...                                ...         ...
# 1619     4 yr Undergrad                   YESHIVA D'MONSEY     PRIVATE
# 1618     4 yr Undergrad  YESHIVA OF NITRA RABBINICAL COLLE     PRIVATE
# 427      4 yr Undergrad  RABBINCAL COL BOBOVER YESHIV BNEI     PRIVATE
# 2706     4 yr Undergrad  YESHIVA SHAAREI TORAH OF ROCKLAND     PRIVATE
# 1888     4 yr Undergrad         YESHIVA OF MACHZIKAI HADAS     PRIVATE
#
#      tap_sector_group  tap_recipient_headcount  tap_recipient_ftes  \
# 6597        1-CUNY SR                       88               55.75
# 2661        1-CUNY SR                       67               50.50
# 2662        1-CUNY SR                     6761             5549.25
# 2663        1-CUNY SR                      115               76.50
# 2664        1-CUNY SR                     1775             1131.50
# ...               ...                      ...                 ...
# 1619   9-CHAPTER XXII                       36               34.00
# 1618   9-CHAPTER XXII                      168              164.50
# 427    9-CHAPTER XXII                      212              220.15
# 2706   9-CHAPTER XXII                       26               23.00
# 1888   9-CHAPTER XXII                      223              220.00
#
#       tap_recipient_dollars
# 6597               23834.50
# 2661              206874.50
# 2662            20935364.66
# 2663              334874.25
# 2664             4481339.66
# ...                     ...
# 1619              130549.50
# 1618              773792.00
# 427              1026561.52
# 2706               95904.00
# 1888             1068463.00
#
# [10232 rows x 11 columns]

# %%
# Save cleaned dataset as a csv file:

tap_college_df.to_csv("Cleaned_TAP_College_Data.csv", index=False, header=True)

# %% [markdown]
# # Part 3: Clean tap_income_df:

# %%
# Sort tap_income_df by TAP sector group:

tap_income_df = tap_income_df.sort_values(by=["TAP Sector Group"])
tap_income_df
# Out:
#         Academic Year Level TAP Level of Study Sector Type TAP Sector Group  \
# 219003           2000     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# 145396           2005     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# 40789            2014     U     5 yr Undergrad      PUBLIC        1-CUNY SR
# 40790            2014     U     5 yr Undergrad      PUBLIC        1-CUNY SR
# 40791            2014     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# ...               ...   ...                ...         ...              ...
# 19674            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 19675            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 19681            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 19684            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 1176             2018     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
#
#        Recipient Age Group   TAP Financial Status  TAP Award Schedule  \
# 219003         age 36 - 50  Financial_Independent  Dependent_Schedule
# 145396         over age 50  Financial_Independent  Dependent_Schedule
# 40789         under age 22    Financial_Dependent  Dependent_Schedule
# 40790          age 22 - 25    Financial_Dependent  Dependent_Schedule
# 40791          over age 50  Financial_Independent  Dependent_Schedule
# ...                    ...                    ...                 ...
# 19674         under age 22    Financial_Dependent  Dependent_Schedule
# 19675          age 22 - 25    Financial_Dependent  Dependent_Schedule
# 19681         under age 22    Financial_Dependent  Dependent_Schedule
# 19684         under age 22    Financial_Dependent  Dependent_Schedule
# 1176           age 22 - 25    Financial_Dependent  Dependent_Schedule
#
#        TAP Degree or NonDegree TAP Schedule Letter Income by $1,000 Range  \
# 219003                  Degree                   A     $ 5,001 to $ 6,000
# 145396                  Degree                   E     $ 8,001 to $ 9,000
# 40789                   Degree                   E     $58,001 to $59,000
# 40790                   Degree                   E     $56,001 to $57,000
# 40791                   Degree                   E     $14,001 to $15,000
# ...                        ...                 ...                    ...
# 19674                   Degree                   E     $30,001 to $31,000
# 19675                   Degree                   E     $25,001 to $26,000
# 19681                   Degree                   E     $20,001 to $21,000
# 19684                   Degree                   E     $11,001 to $12,000
# 1176                    Degree                   E     $27,001 to $28,000
#
#        Income by $5,000 Range Income by $10,000 Range  \
# 219003     $ 5,001 to $10,000      $     0 to $10,000
# 145396     $ 5,001 to $10,000      $     0 to $10,000
# 40789      $55,001 to $60,000      $50,001 to $60,000
# 40790      $55,001 to $60,000      $50,001 to $60,000
# 40791      $10,001 to $15,000      $10,001 to $20,000
# ...                       ...                     ...
# 19674      $30,001 to $35,000      $30,001 to $40,000
# 19675      $25,001 to $30,000      $20,001 to $30,000
# 19681      $20,001 to $25,000      $20,001 to $30,000
# 19684      $10,001 to $15,000      $10,001 to $20,000
# 1176       $25,001 to $30,000      $20,001 to $30,000
#
#         TAP Recipient  Headcount  TAP Recipient FTEs  TAP Recipient Dollars
# 219003                        13                7.67               22170.60
# 145396                         4                2.75               10670.25
# 40789                          1                1.00                 500.00
# 40790                          2                1.00                 500.00
# 40791                          3                1.75                7843.00
# ...                          ...                 ...                    ...
# 19674                         19               18.50               49395.00
# 19675                          1                1.00                3258.00
# 19681                         39               39.00              149974.00
# 19684                         54               54.00              258820.00
# 1176                           1                1.07                3202.85
#
# [219004 rows x 16 columns]

# %%
# Determine which columns contain null values:

tap_income_df.columns[tap_income_df.isnull().any()]
# Out:
# Index(['TAP Recipient FTEs'], dtype='object')

# %%
# Determine what proportion of the column contains null values:

proportion_missing = tap_income_df.isnull().sum()/len(tap_income_df)
proportion_missing = proportion_missing[proportion_missing > 0]
proportion_missing.sort_values(inplace=True)
proportion_missing
# Out:
# TAP Recipient FTEs    0.000009
# dtype: float64

# %%
# Since there are only a few missing values, we will only drop rows with missing values instead of dropping any columns:

tap_income_df = tap_income_df.dropna()
tap_income_df
# Out:
#         Academic Year Level TAP Level of Study Sector Type TAP Sector Group  \
# 219003           2000     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# 145396           2005     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# 40789            2014     U     5 yr Undergrad      PUBLIC        1-CUNY SR
# 40790            2014     U     5 yr Undergrad      PUBLIC        1-CUNY SR
# 40791            2014     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# ...               ...   ...                ...         ...              ...
# 19674            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 19675            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 19681            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 19684            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 1176             2018     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
#
#        Recipient Age Group   TAP Financial Status  TAP Award Schedule  \
# 219003         age 36 - 50  Financial_Independent  Dependent_Schedule
# 145396         over age 50  Financial_Independent  Dependent_Schedule
# 40789         under age 22    Financial_Dependent  Dependent_Schedule
# 40790          age 22 - 25    Financial_Dependent  Dependent_Schedule
# 40791          over age 50  Financial_Independent  Dependent_Schedule
# ...                    ...                    ...                 ...
# 19674         under age 22    Financial_Dependent  Dependent_Schedule
# 19675          age 22 - 25    Financial_Dependent  Dependent_Schedule
# 19681         under age 22    Financial_Dependent  Dependent_Schedule
# 19684         under age 22    Financial_Dependent  Dependent_Schedule
# 1176           age 22 - 25    Financial_Dependent  Dependent_Schedule
#
#        TAP Degree or NonDegree TAP Schedule Letter Income by $1,000 Range  \
# 219003                  Degree                   A     $ 5,001 to $ 6,000
# 145396                  Degree                   E     $ 8,001 to $ 9,000
# 40789                   Degree                   E     $58,001 to $59,000
# 40790                   Degree                   E     $56,001 to $57,000
# 40791                   Degree                   E     $14,001 to $15,000
# ...                        ...                 ...                    ...
# 19674                   Degree                   E     $30,001 to $31,000
# 19675                   Degree                   E     $25,001 to $26,000
# 19681                   Degree                   E     $20,001 to $21,000
# 19684                   Degree                   E     $11,001 to $12,000
# 1176                    Degree                   E     $27,001 to $28,000
#
#        Income by $5,000 Range Income by $10,000 Range  \
# 219003     $ 5,001 to $10,000      $     0 to $10,000
# 145396     $ 5,001 to $10,000      $     0 to $10,000
# 40789      $55,001 to $60,000      $50,001 to $60,000
# 40790      $55,001 to $60,000      $50,001 to $60,000
# 40791      $10,001 to $15,000      $10,001 to $20,000
# ...                       ...                     ...
# 19674      $30,001 to $35,000      $30,001 to $40,000
# 19675      $25,001 to $30,000      $20,001 to $30,000
# 19681      $20,001 to $25,000      $20,001 to $30,000
# 19684      $10,001 to $15,000      $10,001 to $20,000
# 1176       $25,001 to $30,000      $20,001 to $30,000
#
#         TAP Recipient  Headcount  TAP Recipient FTEs  TAP Recipient Dollars
# 219003                        13                7.67               22170.60
# 145396                         4                2.75               10670.25
# 40789                          1                1.00                 500.00
# 40790                          2                1.00                 500.00
# 40791                          3                1.75                7843.00
# ...                          ...                 ...                    ...
# 19674                         19               18.50               49395.00
# 19675                          1                1.00                3258.00
# 19681                         39               39.00              149974.00
# 19684                         54               54.00              258820.00
# 1176                           1                1.07                3202.85
#
# [219002 rows x 16 columns]

# %%
# According to the source, the "Income by $___ Range" columns are all different versions of the same data.
# We will keep the "Income by $10,000 Range" column and remove the other two:

tap_income_df = tap_income_df.drop(columns = ["Income by $1,000 Range", "Income by $5,000 Range"])
tap_income_df
# Out:
#         Academic Year Level TAP Level of Study Sector Type TAP Sector Group  \
# 219003           2000     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# 145396           2005     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# 40789            2014     U     5 yr Undergrad      PUBLIC        1-CUNY SR
# 40790            2014     U     5 yr Undergrad      PUBLIC        1-CUNY SR
# 40791            2014     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# ...               ...   ...                ...         ...              ...
# 19674            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 19675            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 19681            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 19684            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 1176             2018     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
#
#        Recipient Age Group   TAP Financial Status  TAP Award Schedule  \
# 219003         age 36 - 50  Financial_Independent  Dependent_Schedule
# 145396         over age 50  Financial_Independent  Dependent_Schedule
# 40789         under age 22    Financial_Dependent  Dependent_Schedule
# 40790          age 22 - 25    Financial_Dependent  Dependent_Schedule
# 40791          over age 50  Financial_Independent  Dependent_Schedule
# ...                    ...                    ...                 ...
# 19674         under age 22    Financial_Dependent  Dependent_Schedule
# 19675          age 22 - 25    Financial_Dependent  Dependent_Schedule
# 19681         under age 22    Financial_Dependent  Dependent_Schedule
# 19684         under age 22    Financial_Dependent  Dependent_Schedule
# 1176           age 22 - 25    Financial_Dependent  Dependent_Schedule
#
#        TAP Degree or NonDegree TAP Schedule Letter Income by $10,000 Range  \
# 219003                  Degree                   A      $     0 to $10,000
# 145396                  Degree                   E      $     0 to $10,000
# 40789                   Degree                   E      $50,001 to $60,000
# 40790                   Degree                   E      $50,001 to $60,000
# 40791                   Degree                   E      $10,001 to $20,000
# ...                        ...                 ...                     ...
# 19674                   Degree                   E      $30,001 to $40,000
# 19675                   Degree                   E      $20,001 to $30,000
# 19681                   Degree                   E      $20,001 to $30,000
# 19684                   Degree                   E      $10,001 to $20,000
# 1176                    Degree                   E      $20,001 to $30,000
#
#         TAP Recipient  Headcount  TAP Recipient FTEs  TAP Recipient Dollars
# 219003                        13                7.67               22170.60
# 145396                         4                2.75               10670.25
# 40789                          1                1.00                 500.00
# 40790                          2                1.00                 500.00
# 40791                          3                1.75                7843.00
# ...                          ...                 ...                    ...
# 19674                         19               18.50               49395.00
# 19675                          1                1.00                3258.00
# 19681                         39               39.00              149974.00
# 19684                         54               54.00              258820.00
# 1176                           1                1.07                3202.85
#
# [219002 rows x 14 columns]

# %%
# Rename column headers so that they do not contain any spaces. This will be helpful when we load the data into the database:

tap_income_df.columns = ["academic_year", "level", "tap_level_of_study", 
                               "sector_type", "tap_sector_group",
                               "recipient_age_group", "tap_financial_status",
                               "tap_award_schedule", "tap_degree_nondegree",
                               "tap_schedule_letter", "income_by_$10k",
                               "tap_recipient_headcount", "tap_recipient_ftes",
                               "tap_recipient_dollars"]

tap_income_df
# Out:
#         academic_year level tap_level_of_study sector_type tap_sector_group  \
# 219003           2000     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# 145396           2005     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# 40789            2014     U     5 yr Undergrad      PUBLIC        1-CUNY SR
# 40790            2014     U     5 yr Undergrad      PUBLIC        1-CUNY SR
# 40791            2014     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# ...               ...   ...                ...         ...              ...
# 19674            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 19675            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 19681            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 19684            2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 1176             2018     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
#
#        recipient_age_group   tap_financial_status  tap_award_schedule  \
# 219003         age 36 - 50  Financial_Independent  Dependent_Schedule
# 145396         over age 50  Financial_Independent  Dependent_Schedule
# 40789         under age 22    Financial_Dependent  Dependent_Schedule
# 40790          age 22 - 25    Financial_Dependent  Dependent_Schedule
# 40791          over age 50  Financial_Independent  Dependent_Schedule
# ...                    ...                    ...                 ...
# 19674         under age 22    Financial_Dependent  Dependent_Schedule
# 19675          age 22 - 25    Financial_Dependent  Dependent_Schedule
# 19681         under age 22    Financial_Dependent  Dependent_Schedule
# 19684         under age 22    Financial_Dependent  Dependent_Schedule
# 1176           age 22 - 25    Financial_Dependent  Dependent_Schedule
#
#        tap_degree_nondegree tap_schedule_letter      income_by_$10k  \
# 219003               Degree                   A  $     0 to $10,000
# 145396               Degree                   E  $     0 to $10,000
# 40789                Degree                   E  $50,001 to $60,000
# 40790                Degree                   E  $50,001 to $60,000
# 40791                Degree                   E  $10,001 to $20,000
# ...                     ...                 ...                 ...
# 19674                Degree                   E  $30,001 to $40,000
# 19675                Degree                   E  $20,001 to $30,000
# 19681                Degree                   E  $20,001 to $30,000
# 19684                Degree                   E  $10,001 to $20,000
# 1176                 Degree                   E  $20,001 to $30,000
#
#         tap_recipient_headcount  tap_recipient_ftes  tap_recipient_dollars
# 219003                       13                7.67               22170.60
# 145396                        4                2.75               10670.25
# 40789                         1                1.00                 500.00
# 40790                         2                1.00                 500.00
# 40791                         3                1.75                7843.00
# ...                         ...                 ...                    ...
# 19674                        19               18.50               49395.00
# 19675                         1                1.00                3258.00
# 19681                        39               39.00              149974.00
# 19684                        54               54.00              258820.00
# 1176                          1                1.07                3202.85
#
# [219002 rows x 14 columns]

# %%
# Save cleaned dataset as a csv file:

tap_income_df.to_csv("Cleaned_TAP_Income_Data.csv", index=False, header=True)

# %% [markdown]
# The datasets are now ready to be loaded into a PostgresSQL database.

# %% [markdown]
# # Part 4: Create a PostgreSQL database for our data:
#
# We will design our database by using the Quick Database Diagrams tool found at the following link: https://app.quickdatabasediagrams.com/#/. Our database will consist of two tables: tap_college and tap_income. The tap_college table will contain data from tap_college_df, while the tap_income table will contain data from tap_income_df. They can be joined using the tap_sector_group column. An image of our database design is located in the project folder.

# %% [markdown]
# Now that our design is complete, we can create the database in PG Admin and run queries to create the tables. A query.sql file is located in the project folder. Once we run those queries, we will be ready to load our data into the database.

# %% [markdown]
# # Part 5: Load cleaned data into database:
#
# In this part of the project, we will use SQL Alchemy to load data into the database. First, we will create a connection to our database. Then, we will use Pandas to load clean data from both tap_college_df and tap_income_df into their respective tables. Finally, we will make sure that our data has been loaded correctly by querying both tables.

# %%
# Import dependencies:

from sqlalchemy import create_engine
import psycopg2

# %%
# Create a connection to our postgreSQL database:

db_string = f"postgres://postgres:postgres@localhost:5432/tap_db"
engine = create_engine(db_string)

# %%
# Check to make sure that tables are created in the database:

engine.table_names()
# Out:
# ['tap_college', 'tap_income']

# %%
# Load cleaned tap college data into tap_college table:

tap_college_df.to_sql(name="tap_college", con=engine, if_exists='append', index=False)

# %%
# Confirm that the tap college data has been added by querying the tap_college table:

pd.read_sql_query("SELECT * FROM tap_college", con=engine)

# %%
# Load cleaned tap income data into tap_income table:

tap_income_df.to_sql(name="tap_income", con=engine, if_exists='append', index=False)

# %%
# Confirm that the tap income data has been added by querying the tap_income table:

pd.read_sql_query("SELECT * FROM tap_income", con=engine)
# Out:
#         academic_year level tap_level_of_study sector_type tap_sector_group  \
# 0                2000     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# 1                2005     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# 2                2014     U     5 yr Undergrad      PUBLIC        1-CUNY SR
# 3                2014     U     5 yr Undergrad      PUBLIC        1-CUNY SR
# 4                2014     U     4 yr Undergrad      PUBLIC        1-CUNY SR
# ...               ...   ...                ...         ...              ...
# 218997           2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 218998           2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 218999           2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 219000           2016     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
# 219001           2018     U     4 yr Undergrad     PRIVATE   9-CHAPTER XXII
#
#        recipient_age_group   tap_financial_status  tap_award_schedule  \
# 0              age 36 - 50  Financial_Independent  Dependent_Schedule
# 1              over age 50  Financial_Independent  Dependent_Schedule
# 2             under age 22    Financial_Dependent  Dependent_Schedule
# 3              age 22 - 25    Financial_Dependent  Dependent_Schedule
# 4              over age 50  Financial_Independent  Dependent_Schedule
# ...                    ...                    ...                 ...
# 218997        under age 22    Financial_Dependent  Dependent_Schedule
# 218998         age 22 - 25    Financial_Dependent  Dependent_Schedule
# 218999        under age 22    Financial_Dependent  Dependent_Schedule
# 219000        under age 22    Financial_Dependent  Dependent_Schedule
# 219001         age 22 - 25    Financial_Dependent  Dependent_Schedule
#
#        tap_degree_nondegree tap_schedule_letter      income_by_$10k  \
# 0                    Degree                   A  $     0 to $10,000
# 1                    Degree                   E  $     0 to $10,000
# 2                    Degree                   E  $50,001 to $60,000
# 3                    Degree                   E  $50,001 to $60,000
# 4                    Degree                   E  $10,001 to $20,000
# ...                     ...                 ...                 ...
# 218997               Degree                   E  $30,001 to $40,000
# 218998               Degree                   E  $20,001 to $30,000
# 218999               Degree                   E  $20,001 to $30,000
# 219000               Degree                   E  $10,001 to $20,000
# 219001               Degree                   E  $20,001 to $30,000
#
#         tap_recipient_headcount  tap_recipient_ftes  tap_recipient_dollars
# 0                            13                7.67               22170.60
# 1                             4                2.75               10670.25
# 2                             1                1.00                 500.00
# 3                             2                1.00                 500.00
# 4                             3                1.75                7843.00
# ...                         ...                 ...                    ...
# 218997                       19               18.50               49395.00
# 218998                        1                1.00                3258.00
# 218999                       39               39.00              149974.00
# 219000                       54               54.00              258820.00
# 219001                        1                1.07                3202.85
#
# [219002 rows x 14 columns]
